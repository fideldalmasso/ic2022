# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
def intercala_listas(lista1,lista2):
    # Assumes lista1 and lista2 are the same length 
    lista = []

    for i in range(len(lista1)):
        lista.append(lista1[i])
        lista.append(lista2[i])

    return lista

# %%
# step 1

CANT_ENTRENAMIENTO=1000
CANT_PRUEBAS=0
TOTAL = CANT_ENTRENAMIENTO+CANT_PRUEBAS
USAR_MASK = True
mask = ""
if USAR_MASK:
    mask = "_with_mask"

filenames = []
labels = []

for i in range(1,TOTAL+1):
    for type in ['COVID','Normal']:
        filenames.append(f'./dataset/{type}/images{mask}/{type}-{i}.png')
        labels.append(1 if type == 'COVID' else 0)

filenames_train = filenames[0:CANT_ENTRENAMIENTO*2]
labels_train = labels[0:CANT_ENTRENAMIENTO*2]

filenames_test = filenames[CANT_ENTRENAMIENTO*2:TOTAL*2]
labels_test = labels[CANT_ENTRENAMIENTO*2:TOTAL*2]

# %%
# step 2: create a dataset returning slices of `filenames`
datos_train = tf.data.Dataset.from_tensor_slices((filenames_train, labels_train))
datos_test = tf.data.Dataset.from_tensor_slices((filenames_test, labels_test))

# %%
#Obtenemos en variables separadas los datos de entrenamiento (60k) y pruebas (10k)
datos_entrenamiento, datos_pruebas = datos_train, datos_test
datos_entrenamiento
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>

# %%
nombres_clases = ['normal','covid']
nombres_clases
# Out:
# ['normal', 'covid']

# %%
#Funcion de normalizacion para los datos (Pasar de 0-255 a 0-1)
#Hace que la red aprenda mejor y mas rapido

def _parse_function(filename, label):
  image_string = tf.io.read_file(filename)
  image_decoded = tf.image.decode_image(image_string, channels=0)
  image = tf.cast(image_decoded, tf.float32)
  image /= 255 
  return image, label

#Normalizar los datos de entrenamiento y pruebas con la funcion que hicimos
datos_entrenamiento = datos_entrenamiento.map(_parse_function)
#datos_pruebas = datos_pruebas.map(_parse_function)

#Agregar a cache (usar memoria en lugar de disco, entrenamiento mas rapido)
datos_entrenamiento = datos_entrenamiento.cache()
#datos_pruebas = datos_pruebas.cache()

# %%
#Mostrar una imagen de los datos de pruebas, de momento mostremos la primera
for imagen, etiqueta in datos_entrenamiento.take(1):
  break
imagen = imagen.numpy().reshape((299,299)) #Redimensionar, cosas de tensores, lo veremos despues# imagen = imagen.numpy().reshape((28,28)) #Redimensionar, cosas de tensores, lo veremos despues

import matplotlib.pyplot as plt

#Dibujar dibujar
plt.figure()
plt.imshow(imagen, cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
#Dibujar mas
plt.figure(figsize=(10,10))
# for i, (imagen, etiqueta) in enumerate(datos_entrenamiento.take(25)):
for i, (imagen, etiqueta) in enumerate(datos_entrenamiento.take(25)):
  imagen = imagen.numpy().reshape((299,299))
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(imagen, cmap=plt.cm.binary)
  plt.xlabel(nombres_clases[etiqueta])
plt.show()

# %%
#Crear el modelo
modelo = tf.keras.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(299, 299, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(), #1 - blanco y negro
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(1, activation=tf.nn.sigmoid),
  #tf.keras.layers.Dense(10, activation=tf.nn.sigmoid) #Para redes de clasificacion
])

# %%
# modelo = tf.keras.models.Sequential([
#     tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(299, 299, 1)),
#     tf.keras.layers.MaxPooling2D(2, 2),
#     tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
#     tf.keras.layers.MaxPooling2D(2,2),
#     tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
#     tf.keras.layers.MaxPooling2D(2,2),
#     tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
#     tf.keras.layers.MaxPooling2D(2,2),
#     tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
#     tf.keras.layers.MaxPooling2D(2,2),
#     tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
#     tf.keras.layers.MaxPooling2D(2,2),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.Dense(512, activation="sigmoid")
# ])

# %%
#Compilar el modelo
modelo.compile(
    optimizer='adam',
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=['accuracy']
)

# %%
# #Los numeros de datos en entrenamiento y pruebas (60k y 10k)
num_ej_entrenamiento = CANT_ENTRENAMIENTO
num_ej_pruebas = CANT_PRUEBAS

# %%
print(num_ej_entrenamiento)
print(num_ej_pruebas)
# Out:
# 1000
# 0

# %%
#El trabajo por lotes permite que entrenamientos con gran cantidad de datos se haga de manera mas eficiente
TAMANO_LOTE = 32

#Shuffle y repeat hacen que los datos esten mezclados de manera aleatoria para que la red
#no se vaya a aprender el orden de las cosas
#datos_entrenamiento = datos_entrenamiento.repeat().shuffle(num_ej_entrenamiento).batch(TAMANO_LOTE)
#datos_pruebas = datos_pruebas.batch(TAMANO_LOTE)

# %%
from sklearn.model_selection import KFold
import numpy as np
import math
# Define the K-fold Cross Validator
kfold = KFold(n_splits=5, shuffle=True)
# K-fold Cross Validation model evaluation
fold_no = 1
targets = np.concatenate([np.expand_dims(y,axis=0) for x, y in datos_entrenamiento], axis=0)
inputs = np.concatenate([np.expand_dims(x,axis=0) for x, y in datos_entrenamiento], axis=0)
acc_per_fold=[]
loss_per_fold=[]
for j in range (12):
  for train, test in kfold.split(inputs, targets):
    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    # Fit data to model
    history = modelo.fit(inputs[train], targets[train],
              batch_size=TAMANO_LOTE,
              epochs=1,
              steps_per_epoch=math.ceil(num_ej_entrenamiento/TAMANO_LOTE))

    # Generate generalization metrics
    scores = modelo.evaluate(inputs[test], targets[test], verbose=0)
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    print(f'Score for fold {fold_no}: {modelo.metrics_names[0]} of {scores[0]}; {modelo.metrics_names[1]} of {scores[1]*100}%')

    # Increase fold number
    fold_no = fold_no + 1
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# 32/32 [==============================] - 51s 2s/step - loss: 0.5080 - accuracy: 0.7236
# Score for fold 1: loss of 0.22430357336997986; accuracy of 91.75000190734863%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# 32/32 [==============================] - 54s 2s/step - loss: 0.2592 - accuracy: 0.9121
# Score for fold 2: loss of 0.13901983201503754; accuracy of 94.9999988079071%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# 32/32 [==============================] - 47s 1s/step - loss: 0.1866 - accuracy: 0.9365
# Score for fold 3: loss of 0.1966002881526947; accuracy of 95.24999856948853%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# 32/32 [==============================] - 48s 1s/step - loss: 0.1641 - accuracy: 0.9521
# Score for fold 4: loss of 0.23802724480628967; accuracy of 92.75000095367432%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# 32/32 [==============================] - 47s 1s/step - loss: 0.1584 - accuracy: 0.9521
# Score for fold 5: loss of 0.13966192305088043; accuracy of 96.74999713897705%
# ------------------------------------------------------------------------
# Training for fold 6 ...
# 32/32 [==============================] - 48s 1s/step - loss: 0.1626 - accuracy: 0.9521
# Score for fold 6: loss of 0.12309527397155762; accuracy of 96.74999713897705%
# ------------------------------------------------------------------------
# Training for fold 7 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.1190 - accuracy: 0.9678
# Score for fold 7: loss of 0.1630113422870636; accuracy of 94.9999988079071%
# ------------------------------------------------------------------------
# Training for fold 8 ...
# 32/32 [==============================] - 48s 1s/step - loss: 0.1098 - accuracy: 0.9658
# Score for fold 8: loss of 0.15895015001296997; accuracy of 95.74999809265137%
# ------------------------------------------------------------------------
# Training for fold 9 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.1142 - accuracy: 0.9736
# Score for fold 9: loss of 0.07011021673679352; accuracy of 97.50000238418579%
# ------------------------------------------------------------------------
# Training for fold 10 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.1514 - accuracy: 0.9531
# Score for fold 10: loss of 0.0973794236779213; accuracy of 97.50000238418579%
# ------------------------------------------------------------------------
# Training for fold 11 ...
# 32/32 [==============================] - 50s 2s/step - loss: 0.1144 - accuracy: 0.9629
# Score for fold 11: loss of 0.11062037199735641; accuracy of 97.00000286102295%
# ------------------------------------------------------------------------
# Training for fold 12 ...
# 32/32 [==============================] - 51s 2s/step - loss: 0.1172 - accuracy: 0.9648
# Score for fold 12: loss of 0.051239680498838425; accuracy of 98.25000166893005%
# ------------------------------------------------------------------------
# Training for fold 13 ...
# 32/32 [==============================] - 51s 2s/step - loss: 0.0906 - accuracy: 0.9697
# Score for fold 13: loss of 0.1535043567419052; accuracy of 94.9999988079071%
# ------------------------------------------------------------------------
# Training for fold 14 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.1067 - accuracy: 0.9629
# Score for fold 14: loss of 0.07529083639383316; accuracy of 97.25000262260437%
# ------------------------------------------------------------------------
# Training for fold 15 ...
# 32/32 [==============================] - 46s 1s/step - loss: 0.0941 - accuracy: 0.9629
# Score for fold 15: loss of 0.03272329643368721; accuracy of 98.25000166893005%
# ------------------------------------------------------------------------
# Training for fold 16 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0830 - accuracy: 0.9688
# Score for fold 16: loss of 0.07780231535434723; accuracy of 97.25000262260437%
# ------------------------------------------------------------------------
# Training for fold 17 ...
# 32/32 [==============================] - 46s 1s/step - loss: 0.0881 - accuracy: 0.9688
# Score for fold 17: loss of 0.04061058536171913; accuracy of 97.75000214576721%
# ------------------------------------------------------------------------
# Training for fold 18 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0802 - accuracy: 0.9707
# Score for fold 18: loss of 0.07125087082386017; accuracy of 97.00000286102295%
# ------------------------------------------------------------------------
# Training for fold 19 ...
# 32/32 [==============================] - 46s 1s/step - loss: 0.0729 - accuracy: 0.9707
# Score for fold 19: loss of 0.037442125380039215; accuracy of 99.50000047683716%
# ------------------------------------------------------------------------
# Training for fold 20 ...
# 32/32 [==============================] - 46s 1s/step - loss: 0.0761 - accuracy: 0.9736
# Score for fold 20: loss of 0.09192447364330292; accuracy of 97.00000286102295%
# ------------------------------------------------------------------------
# Training for fold 21 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0709 - accuracy: 0.9785
# Score for fold 21: loss of 0.06113012880086899; accuracy of 98.50000143051147%
# ------------------------------------------------------------------------
# Training for fold 22 ...
# 32/32 [==============================] - 46s 1s/step - loss: 0.0709 - accuracy: 0.9736
# Score for fold 22: loss of 0.0518740713596344; accuracy of 98.50000143051147%
# ------------------------------------------------------------------------
# Training for fold 23 ...
# 32/32 [==============================] - 46s 1s/step - loss: 0.0703 - accuracy: 0.9766
# Score for fold 23: loss of 0.04550783708691597; accuracy of 98.50000143051147%
# ------------------------------------------------------------------------
# Training for fold 24 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0658 - accuracy: 0.9766
# Score for fold 24: loss of 0.04168007895350456; accuracy of 98.7500011920929%
# ------------------------------------------------------------------------
# Training for fold 25 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0463 - accuracy: 0.9775
# Score for fold 25: loss of 0.0333411805331707; accuracy of 98.7500011920929%
# ------------------------------------------------------------------------
# Training for fold 26 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0407 - accuracy: 0.9834
# Score for fold 26: loss of 0.028198199346661568; accuracy of 99.00000095367432%
# ------------------------------------------------------------------------
# Training for fold 27 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0576 - accuracy: 0.9805
# Score for fold 27: loss of 0.013741415925323963; accuracy of 99.25000071525574%
# ------------------------------------------------------------------------
# Training for fold 28 ...
# 32/32 [==============================] - 48s 2s/step - loss: 0.0456 - accuracy: 0.9844
# Score for fold 28: loss of 0.04338409751653671; accuracy of 98.25000166893005%
# ------------------------------------------------------------------------
# Training for fold 29 ...
# 32/32 [==============================] - 56s 2s/step - loss: 0.0480 - accuracy: 0.9834
# Score for fold 29: loss of 0.025357777252793312; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 30 ...
# 32/32 [==============================] - 52s 2s/step - loss: 0.0393 - accuracy: 0.9863
# Score for fold 30: loss of 0.02464159019291401; accuracy of 99.00000095367432%
# ------------------------------------------------------------------------
# Training for fold 31 ...
# 32/32 [==============================] - 55s 2s/step - loss: 0.0247 - accuracy: 0.9922
# Score for fold 31: loss of 0.021257316693663597; accuracy of 99.00000095367432%
# ------------------------------------------------------------------------
# Training for fold 32 ...
# 32/32 [==============================] - 53s 2s/step - loss: 0.0414 - accuracy: 0.9844
# Score for fold 32: loss of 0.012120948173105717; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 33 ...
# 32/32 [==============================] - 58s 2s/step - loss: 0.0519 - accuracy: 0.9775
# Score for fold 33: loss of 0.018008768558502197; accuracy of 99.00000095367432%
# ------------------------------------------------------------------------
# Training for fold 34 ...
# 32/32 [==============================] - 55s 2s/step - loss: 0.0324 - accuracy: 0.9922
# Score for fold 34: loss of 0.007624589838087559; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 35 ...
# 32/32 [==============================] - 51s 2s/step - loss: 0.0478 - accuracy: 0.9834
# Score for fold 35: loss of 0.08776243031024933; accuracy of 97.00000286102295%
# ------------------------------------------------------------------------
# Training for fold 36 ...
# 32/32 [==============================] - 52s 2s/step - loss: 0.0550 - accuracy: 0.9863
# Score for fold 36: loss of 0.045278534293174744; accuracy of 97.75000214576721%
# ------------------------------------------------------------------------
# Training for fold 37 ...
# 32/32 [==============================] - 51s 2s/step - loss: 0.0264 - accuracy: 0.9912
# Score for fold 37: loss of 0.010829757899045944; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 38 ...
# 32/32 [==============================] - 50s 2s/step - loss: 0.0237 - accuracy: 0.9922
# Score for fold 38: loss of 0.007426193915307522; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 39 ...
# 32/32 [==============================] - 50s 2s/step - loss: 0.0137 - accuracy: 0.9951
# Score for fold 39: loss of 0.0007839883910492063; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 40 ...
# 32/32 [==============================] - 51s 2s/step - loss: 0.0127 - accuracy: 0.9961
# Score for fold 40: loss of 0.030141985043883324; accuracy of 99.50000047683716%
# ------------------------------------------------------------------------
# Training for fold 41 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.0358 - accuracy: 0.9834
# Score for fold 41: loss of 0.10716885328292847; accuracy of 97.00000286102295%
# ------------------------------------------------------------------------
# Training for fold 42 ...
# 32/32 [==============================] - 50s 2s/step - loss: 0.0519 - accuracy: 0.9814
# Score for fold 42: loss of 0.0618291050195694; accuracy of 97.75000214576721%
# ------------------------------------------------------------------------
# Training for fold 43 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.0297 - accuracy: 0.9863
# Score for fold 43: loss of 0.021731872111558914; accuracy of 99.25000071525574%
# ------------------------------------------------------------------------
# Training for fold 44 ...
# 32/32 [==============================] - 48s 1s/step - loss: 0.0356 - accuracy: 0.9912
# Score for fold 44: loss of 0.024415379390120506; accuracy of 99.25000071525574%
# ------------------------------------------------------------------------
# Training for fold 45 ...
# 32/32 [==============================] - 48s 1s/step - loss: 0.0367 - accuracy: 0.9844
# Score for fold 45: loss of 0.011001440696418285; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 46 ...
# 32/32 [==============================] - 48s 2s/step - loss: 0.0126 - accuracy: 0.9961
# Score for fold 46: loss of 0.00591241754591465; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 47 ...
# 32/32 [==============================] - 51s 2s/step - loss: 0.0086 - accuracy: 0.9980
# Score for fold 47: loss of 0.012923953123390675; accuracy of 99.50000047683716%
# ------------------------------------------------------------------------
# Training for fold 48 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.0607 - accuracy: 0.9824
# Score for fold 48: loss of 0.010915874503552914; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 49 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.0257 - accuracy: 0.9922
# Score for fold 49: loss of 0.012224406935274601; accuracy of 99.50000047683716%
# ------------------------------------------------------------------------
# Training for fold 50 ...
# 32/32 [==============================] - 47s 1s/step - loss: 0.0093 - accuracy: 0.9971
# Score for fold 50: loss of 0.0020312375854700804; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 51 ...
# 32/32 [==============================] - 49s 2s/step - loss: 0.0185 - accuracy: 0.9961
# Score for fold 51: loss of 0.0032530189491808414; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 52 ...
# 32/32 [==============================] - 46s 1s/step - loss: 0.0125 - accuracy: 0.9961
# Score for fold 52: loss of 0.0038749927189201117; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 53 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0033 - accuracy: 0.9990
# Score for fold 53: loss of 0.0024955684784799814; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 54 ...
# 32/32 [==============================] - 44s 1s/step - loss: 0.0063 - accuracy: 0.9971
# Score for fold 54: loss of 0.003529957728460431; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 55 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0116 - accuracy: 0.9941
# Score for fold 55: loss of 0.003021243028342724; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 56 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0191 - accuracy: 0.9922
# Score for fold 56: loss of 0.0014575060922652483; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 57 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0333 - accuracy: 0.9902
# Score for fold 57: loss of 0.010286110453307629; accuracy of 99.25000071525574%
# ------------------------------------------------------------------------
# Training for fold 58 ...
# 32/32 [==============================] - 44s 1s/step - loss: 0.0186 - accuracy: 0.9941
# Score for fold 58: loss of 0.003828909946605563; accuracy of 99.75000023841858%
# ------------------------------------------------------------------------
# Training for fold 59 ...
# 32/32 [==============================] - 44s 1s/step - loss: 0.0087 - accuracy: 0.9971
# Score for fold 59: loss of 0.0011234561679884791; accuracy of 100.0%
# ------------------------------------------------------------------------
# Training for fold 60 ...
# 32/32 [==============================] - 45s 1s/step - loss: 0.0079 - accuracy: 0.9971
# Score for fold 60: loss of 0.000670340727083385; accuracy of 100.0%

# %%
import math
#Entrenar
#historial = modelo.fit(datos_entrenamiento, epochs=60,batch_size=TAMANO_LOTE, steps_per_epoch=math.ceil(num_ej_entrenamiento/TAMANO_LOTE),validation_data = datos_pruebas,validation_batch_size=TAMANO_LOTE, validation_steps=math.ceil(num_ej_pruebas/TAMANO_LOTE))

# %%
#Ver la funcion de perdida
import matplotlib.ticker as mtick
plt.xlabel("# Epoca")
plt.ylabel("Loss")
ax = plt.plot(loss_per_fold)
#ax = plt.plot(historial.history["val_accuracy"])

# %%
#Ver la funcion de perdida
import matplotlib.ticker as mtick
plt.xlabel("# Epoca")
plt.ylabel("Accuracy")
ax = plt.plot(acc_per_fold)
#ax = plt.plot(historial.history["val_accuracy"])

# %%
#Pintar una cuadricula con varias predicciones, y marcar si fue correcta (azul) o incorrecta (roja)
import numpy as np
datos_entrenamiento = datos_entrenamiento.repeat().shuffle(num_ej_entrenamiento).batch(TAMANO_LOTE)
for imagenes_prueba, etiquetas_prueba in datos_entrenamiento.take(1):
  imagenes_prueba = imagenes_prueba.numpy()
  etiquetas_prueba = etiquetas_prueba.numpy()
  predicciones = modelo.predict(imagenes_prueba)
  
def graficar_imagen(i, arr_predicciones, etiquetas_reales, imagenes):
  arr_predicciones, etiqueta_real, img = arr_predicciones[i], etiquetas_reales[i], imagenes[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  
  plt.imshow(img[...,0], cmap=plt.cm.binary)

  etiqueta_prediccion = np.rint(arr_predicciones[0]).astype(int)
  if etiqueta_prediccion == etiqueta_real:
    color = 'blue'
  else:
    color = 'red'
  plt.xlabel("{} {:2.0f}% ({})".format(nombres_clases[etiqueta_prediccion],
                                100*np.max(arr_predicciones),
                                nombres_clases[etiqueta_real]),
                                color=color)
  
def graficar_valor_arreglo(i, arr_predicciones, etiqueta_real):
  arr_predicciones, etiqueta_real = arr_predicciones[i], etiqueta_real[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  grafica = plt.bar(range(1), arr_predicciones, color="#777777")
  plt.ylim([0, 1]) 
  etiqueta_prediccion = np.rint(arr_predicciones).astype(int)
  if etiqueta_real==etiqueta_prediccion: 
    grafica[0].set_color('blue')
  else:
    grafica[0].set_color('red')
  
filas = 4
columnas = 8
num_imagenes = filas*columnas
plt.figure(figsize=(2*2*columnas, 2*filas))
for i in range(num_imagenes):
  plt.subplot(filas, 2*columnas, 2*i+1)
  graficar_imagen(i, predicciones, etiquetas_prueba, imagenes_prueba)
  plt.subplot(filas, 2*columnas, 2*i+2)
  graficar_valor_arreglo(i, predicciones, etiquetas_prueba)
# Out:
# 1/1 [==============================] - 1s 503ms/step

# %%
#Probar una imagen suelta
imagen = imagenes_prueba[4] #AL ser la variable imagenes_prueba solo tiene lo que se le puso en el bloque anterior heheh
imagen = np.array([imagen])
prediccion = modelo.predict(imagen)

print("Prediccion: " + nombres_clases[np.argmax(prediccion[0])])
# Out:
# 1/1 [==============================] - 0s 134ms/step
# Prediccion: normal
